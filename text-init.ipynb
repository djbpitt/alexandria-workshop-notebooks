# %%
from alexandria.notebook.alexandria_proxy import AlexandriaProxy

alexandria = AlexandriaProxy("http://localhost:2015/","admin")
text = alexandria.add_text('data/grotius-3160-v2.xml')
print(text)
# Out:
# ConnectionRefusedErrorTraceback (most recent call last)
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      90     if err is not None:
# ---> 91         raise err
#      92
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      80                 sock.bind(source_address)
# ---> 81             sock.connect(sa)
#      82             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionErrorTraceback (most recent call last)
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     361         else:
# --> 362             conn.request(method, url, **httplib_request_kw)
#     363
#
# C:\Users\bramb\Anaconda3\lib\http\client.py in request(self, method, url, body, headers)
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#
# C:\Users\bramb\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#
# C:\Users\bramb\Anaconda3\lib\http\client.py in endheaders(self, message_body)
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#
# C:\Users\bramb\Anaconda3\lib\http\client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# C:\Users\bramb\Anaconda3\lib\http\client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     150             raise NewConnectionError(
# --> 151                 self, "Failed to establish a new connection: %s" % e)
#     152
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x00000000046E39B0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryErrorTraceback (most recent call last)
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     622             retries = retries.increment(method, url, error=e, _pool=self,
# --> 623                                         _stacktrace=sys.exc_info()[2])
#     624             retries.sleep()
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     280         if new_retry.is_exhausted():
# --> 281             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     282
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=2015): Max retries exceeded with url: /resources (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x00000000046E39B0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionErrorTraceback (most recent call last)
# <ipython-input-1-d6a7b9301f75> in <module>()
#       2
#       3 alexandria = AlexandriaProxy("http://localhost:2015/","admin")
# ----> 4 text = alexandria.add_text('data/grotius-3160-v2.xml')
#       5 print(text)
#
# C:\Users\bramb\workspaces\python\alexandria-workshop-notebooks\alexandria\notebook\alexandria_proxy.py in add_text(self, path)
#      13
#      14     def add_text(self, path):
# ---> 15         uuid = self.alexandria.resources.add(ResourcePrototype(path)).uuid
#      16         rp = ResourceProxy(path, uuid, self.alexandria)
#      17         with open(path, 'r') as f:
#
# C:\Users\bramb\workspaces\python\alexandria-workshop-notebooks\alexandria\client\resources_endpoint.py in add(self, proto)
#      18             return self.alexandria.post(self.endpoint, proto.entity)
#      19
# ---> 20         add_result = RestRequester(adder).on_status(HTTPStatus.CREATED, util.location_as_uuid).invoke()
#      21
#      22         if self.alexandria.auto_confirm and not add_result.failed:
#
# C:\Users\bramb\workspaces\python\alexandria-workshop-notebooks\alexandria\client\rest_requester.py in invoke(self)
#      12
#      13     def invoke(self):
# ---> 14         response = self.response_supplier()
#      15         try:
#      16             return self.status_mappers[response.status_code](response)
#
# C:\Users\bramb\workspaces\python\alexandria-workshop-notebooks\alexandria\client\resources_endpoint.py in adder()
#      16     def add(self, proto):
#      17         def adder():
# ---> 18             return self.alexandria.post(self.endpoint, proto.entity)
#      19
#      20         add_result = RestRequester(adder).on_status(HTTPStatus.CREATED, util.location_as_uuid).invoke()
#
# C:\Users\bramb\workspaces\python\alexandria-workshop-notebooks\alexandria\client\alexandria.py in post(self, uri, data)
#      45     def post(self, uri, data):
#      46         url = urljoin(self.server, uri)
# ---> 47         r = self.session.post(url=url, json=data)
#      48         r.raise_for_status()
#      49         return r
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     516         """
#     517
# --> 518         return self.request('POST', url, data=data, json=json, **kwargs)
#     519
#     520     def put(self, url, data=None, **kwargs):
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# C:\Users\bramb\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     465                 raise ProxyError(e, request=request)
#     466
# --> 467             raise ConnectionError(e, request=request)
#     468
#     469         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=2015): Max retries exceeded with url: /resources (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x00000000046E39B0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))

# %%
print(text.get_xml())

# %%
text.show_graph()
